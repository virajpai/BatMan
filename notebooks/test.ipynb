# %%
import pandas as pd
import sys
sys.path.append('../')

# %%
from utils.db_utils import DbOps
from utils.db_models import Job

# %%
dbops = DbOps()

# %%
dbops.db_path = "sqlite:///../data/scheduler.db"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dbops.db_path = "sqlite:///../data/scheduler.db"
#
# AttributeError: property 'db_path' of 'DbOps' object has no setter
